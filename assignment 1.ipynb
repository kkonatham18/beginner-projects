# %%
##### ASSIGNMENT 1
# 1.LOADING THE UBER.CSV DATA SET
import pandas as pd  
uber_data=pd.read_csv("uber.csv")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
## 2. DISPLAYING THE NUMBER OF ROWS AND NUMBER OF COLUMNS 
print(uber_data.shape)
# Out:
# (1156, 7)

# %%
3 ## SHOW TH EUNIQUE CATEGORIES IN THE CATEGORY COLUMN
print(uber_data['CATEGORY*'].unique())
# Out:
# ['Business' 'Personal' nan]

# %%
## 4. FINDING HOW MANY NULL ROWS IN THE PURPOSE COLUMN
null_rows=uber_data[uber_data['PURPOSE*'].isnull()]
null_rows
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %%
## 5. RENAME ALL THE COLUMNS IN UPPERCASE
# 5. RENAME ALL THE COLUMNS IN UPPERCASE
uber_data = uber_data.rename(columns={'START_DATE*': 'START','END_DATE*': 'END','CATEGORY*': 'CATEGORY','START*': 'STA','STOP*': 'STP','MILES*': 'MILES','PURPOSE*': 'PURPOSE'})
uber_data
# Out:
#                    START                 END  CATEGORY               STA  \
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 32   2016-01-19 09:09:00 2016-01-19 09:23:00  Business       Whitebridge
# 85   2016-02-09 10:54:00 2016-02-09 11:07:00  Personal       Whitebridge
# 86   2016-02-09 11:43:00 2016-02-09 11:50:00  Personal        Northwoods
# 87   2016-02-09 13:36:00 2016-02-09 13:52:00  Personal        Tanglewood
# ...                  ...                 ...       ...               ...
# 1066 2016-12-19 14:37:00 2016-12-19 14:50:00  Business  Unknown Location
# 1069 2016-12-19 19:05:00 2016-12-19 19:17:00  Business         Islamabad
# 1071 2016-12-20 08:49:00 2016-12-20 09:24:00  Business  Unknown Location
# 1143 2016-12-29 20:53:00 2016-12-29 21:42:00  Business           Kar?chi
# 1155                 NaT                 NaT       NaN               NaN
#
#                       STP    MILES PURPOSE NEW_COLUMN   TRIP_DURATION
# ...
